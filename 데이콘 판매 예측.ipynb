# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# 'C:\\Users\\xorud\\Desktop\\동아리\\개인 프로젝트\\데이콘 쇼핑몰 지점별 매출액 예측\\dataset\\dataset'

# %%
os.chdir('C:\\Users\\xorud\\Desktop\\동아리\\개인 프로젝트\\데이콘 쇼핑몰 지점별 매출액 예측\\dataset\\dataset')

# %%
df = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
df
# Out:
#         id  Store        Date  Temperature  Fuel_Price  Promotion1  \
# 0        1      1  05/02/2010        42.31       2.572         NaN
# 1        2      1  12/02/2010        38.51       2.548         NaN
# 2        3      1  19/02/2010        39.93       2.514         NaN
# 3        4      1  26/02/2010        46.63       2.561         NaN
# 4        5      1  05/03/2010        46.50       2.625         NaN
# ...    ...    ...         ...          ...         ...         ...
# 6250  6251     45  31/08/2012        75.09       3.867    23641.30
# 6251  6252     45  07/09/2012        75.70       3.911    11024.45
# 6252  6253     45  14/09/2012        67.87       3.948    11407.95
# 6253  6254     45  21/09/2012        65.32       4.038     8452.20
# 6254  6255     45  28/09/2012        64.88       3.997     4556.61
#
#       Promotion2  Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  \
# 0            NaN         NaN         NaN         NaN         8.106      False
# ...

# %%
test
# Out:
#       id  Store        Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0      1      1  05/10/2012        68.55       3.617     8077.89         NaN
# 1      2      1  12/10/2012        62.99       3.601     2086.18         NaN
# 2      3      1  19/10/2012        67.97       3.594      950.33         NaN
# 3      4      1  26/10/2012        69.16       3.506     2585.85       31.75
# 4      5      2  05/10/2012        70.27       3.617     6037.76         NaN
# ..   ...    ...         ...          ...         ...         ...         ...
# 175  176     44  26/10/2012        46.97       3.755       38.65        2.61
# 176  177     45  05/10/2012        64.89       3.985     5046.74         NaN
# 177  178     45  12/10/2012        54.47       4.000     1956.28         NaN
# 178  179     45  19/10/2012        56.47       3.969     2004.02         NaN
# 179  180     45  26/10/2012        58.85       3.882     4018.91       58.08
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6255 entries, 0 to 6254
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            6255 non-null   int64
#  1   Store         6255 non-null   int64
#  2   Date          6255 non-null   object
#  3   Temperature   6255 non-null   float64
#  4   Fuel_Price    6255 non-null   float64
#  5   Promotion1    2102 non-null   float64
#  6   Promotion2    1592 non-null   float64
#  7   Promotion3    1885 non-null   float64
#  8   Promotion4    1819 non-null   float64
#  9   Promotion5    2115 non-null   float64
#  10  Unemployment  6255 non-null   float64
#  11  IsHoliday     6255 non-null   bool
#  12  Weekly_Sales  6255 non-null   float64
# dtypes: bool(1), float64(9), int64(2), object(1)
# memory usage: 592.6+ KB

# %%
df.drop_duplicates() # 중복값 없음.
# Out:
#         id  Store        Date  Temperature  Fuel_Price  Promotion1  \
# 0        1      1  05/02/2010        42.31       2.572         NaN
# 1        2      1  12/02/2010        38.51       2.548         NaN
# 2        3      1  19/02/2010        39.93       2.514         NaN
# 3        4      1  26/02/2010        46.63       2.561         NaN
# 4        5      1  05/03/2010        46.50       2.625         NaN
# ...    ...    ...         ...          ...         ...         ...
# 6250  6251     45  31/08/2012        75.09       3.867    23641.30
# 6251  6252     45  07/09/2012        75.70       3.911    11024.45
# 6252  6253     45  14/09/2012        67.87       3.948    11407.95
# 6253  6254     45  21/09/2012        65.32       4.038     8452.20
# 6254  6255     45  28/09/2012        64.88       3.997     4556.61
#
#       Promotion2  Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  \
# 0            NaN         NaN         NaN         NaN         8.106      False
# ...

# %%
df.isnull().sum()
# Out:
# id                 0
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# Promotion1      4153
# Promotion2      4663
# Promotion3      4370
# Promotion4      4436
# Promotion5      4140
# Unemployment       0
# IsHoliday          0
# Weekly_Sales       0
# dtype: int64

# %%
#df = df.fillna(df.median())
#df

# %%
df.describe() # 프로모션 2,3은 -값이 있음. 왜?
# Out:
#                 id        Store  Temperature   Fuel_Price    Promotion1  \
# count  6255.000000  6255.000000  6255.000000  6255.000000   2102.000000
# mean   3128.000000    23.000000    60.639199     3.344369   7155.930661
# std    1805.807299    12.988211    18.624094     0.455364   8408.206085
# min       1.000000     1.000000    -2.060000     2.472000      0.270000
# 25%    1564.500000    12.000000    47.170000     2.917000   1844.295000
# 50%    3128.000000    23.000000    62.720000     3.413000   5221.140000
# 75%    4691.500000    34.000000    75.220000     3.722000   9199.242500
# max    6255.000000    45.000000   100.140000     4.308000  88646.760000
#
#           Promotion2     Promotion3    Promotion4     Promotion5  \
# count    1592.000000    1885.000000   1819.000000    2115.000000
# mean     3308.125810    1462.535523   3465.952501    4518.993173
# std      9382.823804    9667.580258   6413.116294    6048.661908
# ...

# %%
df.loc[df['Promotion2'] < 0]
# Out:
#         id  Store        Date  Temperature  Fuel_Price  Promotion1  \
# 528    529      4  23/03/2012        59.07       3.759     8806.80
# 688    689      5  17/08/2012        87.52       3.571     1649.56
# 1243  1244      9  10/08/2012        88.66       3.494     3180.78
# 1247  1248      9  07/09/2012        87.93       3.730     4837.99
# 1361  1362     10  16/03/2012        62.11       4.273     3977.45
# 1379  1380     10  20/07/2012        84.45       3.589     6596.80
# 1655  1656     12  06/07/2012        89.13       3.765    10804.73
# 1934  1935     14  13/07/2012        79.97       3.523     9158.47
# 2079  2080     15  24/08/2012        66.98       3.997     3669.07
# 2220  2221     16  07/09/2012        60.09       3.596     2291.22
# 2618  2619     19  27/04/2012        42.45       4.163     3735.30
# 2776  2777     20  07/09/2012        76.36       3.911    11783.56
# 3315  3316     24  11/05/2012        58.70       4.055     6503.15
# ...

# %%
df['Date']
# Out:
# 0       05/02/2010
# 1       12/02/2010
# 2       19/02/2010
# 3       26/02/2010
# 4       05/03/2010
#            ...
# 6250    31/08/2012
# 6251    07/09/2012
# 6252    14/09/2012
# 6253    21/09/2012
# 6254    28/09/2012
# Name: Date, Length: 6255, dtype: object

# %%
pd.to_datetime(df['Date'])
# Out:
# 0      2010-05-02
# 1      2010-12-02
# 2      2010-02-19
# 3      2010-02-26
# 4      2010-05-03
#           ...
# 6250   2012-08-31
# 6251   2012-07-09
# 6252   2012-09-14
# 6253   2012-09-21
# 6254   2012-09-28
# Name: Date, Length: 6255, dtype: datetime64[ns]

# %%
df['date'] = pd.to_datetime(df['Date']) # datetime으로 변경

# %%
df
# Out:
#         id  Store        Date  Temperature  Fuel_Price  Promotion1  \
# 0        1      1  05/02/2010        42.31       2.572         NaN
# 1        2      1  12/02/2010        38.51       2.548         NaN
# 2        3      1  19/02/2010        39.93       2.514         NaN
# 3        4      1  26/02/2010        46.63       2.561         NaN
# 4        5      1  05/03/2010        46.50       2.625         NaN
# ...    ...    ...         ...          ...         ...         ...
# 6250  6251     45  31/08/2012        75.09       3.867    23641.30
# 6251  6252     45  07/09/2012        75.70       3.911    11024.45
# 6252  6253     45  14/09/2012        67.87       3.948    11407.95
# 6253  6254     45  21/09/2012        65.32       4.038     8452.20
# 6254  6255     45  28/09/2012        64.88       3.997     4556.61
#
#       Promotion2  Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  \
# 0            NaN         NaN         NaN         NaN         8.106      False
# ...

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
df['day_name'] = df['date'].dt.day_name()

# %%
df
# Out:
#         id  Store        Date  Temperature  Fuel_Price  Promotion1  \
# 0        1      1  05/02/2010        42.31       2.572         NaN
# 1        2      1  12/02/2010        38.51       2.548         NaN
# 2        3      1  19/02/2010        39.93       2.514         NaN
# 3        4      1  26/02/2010        46.63       2.561         NaN
# 4        5      1  05/03/2010        46.50       2.625         NaN
# ...    ...    ...         ...          ...         ...         ...
# 6250  6251     45  31/08/2012        75.09       3.867    23641.30
# 6251  6252     45  07/09/2012        75.70       3.911    11024.45
# 6252  6253     45  14/09/2012        67.87       3.948    11407.95
# 6253  6254     45  21/09/2012        65.32       4.038     8452.20
# 6254  6255     45  28/09/2012        64.88       3.997     4556.61
#
#       Promotion2  Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  \
# 0            NaN         NaN         NaN         NaN         8.106      False
# ...

# %%
pd.pivot_table(data=df, index = 'day_name', values = 'Weekly_Sales')
# Out:
#            Weekly_Sales
# day_name
# Friday     1.039147e+06
# Monday     1.095299e+06
# Saturday   1.046277e+06
# Sunday     1.053356e+06
# Thursday   1.059402e+06
# Tuesday    1.070389e+06
# Wednesday  1.030142e+06

# %%
df['day_name'].value_counts()
# Out:
# Friday       4230
# Monday        450
# Sunday        405
# Thursday      405
# Tuesday       405
# Saturday      270
# Wednesday      90
# Name: day_name, dtype: int64

# %%
pd.pivot_table(data=df, index = 'Store', values = 'Weekly_Sales')
# Out:
#        Weekly_Sales
# Store
# 1      1.555088e+06
# 2      1.926625e+06
# 3      4.021757e+05
# 4      2.093196e+06
# 5      3.178013e+05
# 6      1.567700e+06
# 7      5.724965e+05
# 8      9.083112e+05
# 9      5.433975e+05
# 10     1.904070e+06
# 11     1.358239e+06
# 12     1.010337e+06
# 13     2.003047e+06
# 14     2.031497e+06
# 15     6.251386e+05
# 16     5.196860e+05
# 17     8.921499e+05
# 18     1.084692e+06
# 19     1.447704e+06
# 20     2.107607e+06
# 21     7.589676e+05
# 22     1.028700e+06
# 23     1.389658e+06
# 24     1.356981e+06
# 25     7.071212e+05
# 26     1.002461e+06
# 27     1.778997e+06
# 28     1.325450e+06
# 29     5.399662e+05
# 30     4.385509e+05
# 31     1.396622e+06
# 32     1.165615e+06
# 33     2.596752e+05
# 34     9.669910e+05
# 35     9.214859e+05
# 36     3.760791e+05
# 37     5.183317e+05
# 38     3.843002e+05
# 39     1.447696e+06
# 40     9.638794e+05
# 41     1.265392e+06
# 42     5.561442e+05
# 43     6.337549e+05
# 44     3.016767e+05
# ...

# %%
plt.hist(df.Weekly_Sales, bins=50)
plt.show()

# %%
sns.distplot(df['Weekly_Sales'])
# Out:
# C:\Users\xorud\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weekly_Sales', ylabel='Density'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df['Temperature'])
plt.show()

# %%
sns.distplot(df['Temperature'])
# Out:
# C:\Users\xorud\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Temperature', ylabel='Density'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df['Fuel_Price'])
plt.show()

# %%
sns.distplot(df['Fuel_Price'])
# Out:
# C:\Users\xorud\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fuel_Price', ylabel='Density'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df['Promotion1'])
plt.show()

# %%
sns.distplot(df['Promotion1'])
# Out:
# C:\Users\xorud\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Promotion1', ylabel='Density'>

# %%
sns.distplot(df['Promotion2'])
# Out:
# C:\Users\xorud\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Promotion2', ylabel='Density'>

# %%
sns.distplot(df['Promotion3'])
# Out:
# C:\Users\xorud\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Promotion3', ylabel='Density'>

# %%
sns.distplot(df['Promotion4'])
# Out:
# C:\Users\xorud\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Promotion4', ylabel='Density'>

# %%
sns.distplot(df['Promotion5'])
# Out:
# C:\Users\xorud\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Promotion5', ylabel='Density'>

# %%
sns.distplot(df['Unemployment'])
# Out:
# C:\Users\xorud\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Unemployment', ylabel='Density'>

# %%
sns.countplot(x = 'IsHoliday',data = df)
# Out:
# <AxesSubplot:xlabel='IsHoliday', ylabel='count'>

# %%
sns.countplot(x = 'year',data = df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
sns.countplot(x = 'month',data = df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='count'>

# %%
sns.countplot(x = 'day_name',data = df)
# Out:
# <AxesSubplot:xlabel='day_name', ylabel='count'>

# %%
# 프로모션들 끼리 상관성이 있나? promotion 값을 임의로 넣어도 되나? 난 promotion이
# 기업의 이득이라고 생각했는데

# %%
plt.rcParams['figure.figsize'] = [20, 10]
sns.heatmap(df.corr(), annot = True) # 상관분석
# Out:
# <AxesSubplot:>

# %%
# promotion을 할인율 같은 값으로 인식할 시 0으로 결측치를 채우고 -값 삭제. 
# promotion을 할인으로 인한 기업의 이득으로 인식할 시 -값 삭제 못함. 결측치 고민.
# 난 후자를 선택함. 그럼 결측치를 프로모션을 진행했을 때 얼만큼의 이익이 생겼는지를 고민 .
